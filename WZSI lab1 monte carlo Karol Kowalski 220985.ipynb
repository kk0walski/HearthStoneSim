# %%
import pandas as pd 
aggressive = pd.read_csv("Dane/aggresive.csv", sep=';')
passive = pd.read_csv("Dane/passive.csv", sep=';')
random = pd.read_csv("Dane/random.csv", sep=';')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-3fec6425634b> in <module>
# ----> 1 import pandas as pd
#       2 aggressive = pd.read_csv("Dane/aggresive.csv", sep=';')
#       3 passive = pd.read_csv("Dane/passive.csv", sep=';')
#       4 random = pd.read_csv("Dane/random.csv", sep=';')
#
# ~/PycharmProjects/VSBayes/venv/lib/python3.6/site-packages/pandas/__init__.py in <module>
#      21
#      22 # numpy compat
# ---> 23 from pandas.compat.numpy import *
#      24
#      25 try:
#
# ~/PycharmProjects/VSBayes/venv/lib/python3.6/site-packages/pandas/compat/__init__.py in <module>
#      30 import functools
#      31 import itertools
# ---> 32 from distutils.version import LooseVersion
#      33 from itertools import product
#      34 import sys
#
# ~/PycharmProjects/VSBayes/venv/lib/python3.6/distutils/__init__.py in <module>
#      42     __version__ = real_distutils.__version__
#      43
# ---> 44 from distutils import dist, sysconfig  # isort:skip
#      45
#      46 try:
#
# ImportError: cannot import name 'dist'

# %%
aggressive.describe()
# Out:
#        single_move_time  round_time  mcts_win  maximal_number_of_playouts  \
# count        180.000000  180.000000     180.0                  180.000000
# mean           3.777778   20.222222       1.0                72703.055556
# std            2.353069   16.112577       0.0                42046.386927
# min            1.000000    2.000000       1.0                 3174.000000
# 25%            2.000000   10.000000       1.0                41143.750000
# 50%            4.000000   20.000000       1.0                83728.500000
# 75%            6.000000   20.000000       1.0               101181.000000
# max            8.000000   60.000000       1.0               160599.000000
#
#        max_tree_depth
# count           180.0
# mean              2.0
# std               0.0
# min               2.0
# 25%               2.0
# 50%               2.0
# 75%               2.0
# max               2.0

# %%
passive.describe()
# Out:
#        single_move_time  round_time  mcts_win  maximal_number_of_playouts  \
# count        240.000000  240.000000     240.0                  240.000000
# mean           5.166667   13.500000       1.0               106328.358333
# std            3.190817    5.907233       0.0                74494.360532
# min            1.000000    2.000000       1.0                10432.000000
# 25%            2.000000   10.000000       1.0                31965.750000
# 50%            5.000000   10.000000       1.0                96640.500000
# 75%            8.000000   20.000000       1.0               173812.500000
# max           10.000000   20.000000       1.0               233771.000000
#
#        max_tree_depth
# count           240.0
# mean              2.0
# std               0.0
# min               2.0
# 25%               2.0
# 50%               2.0
# 75%               2.0
# max               2.0

# %%
random.describe()
# Out:
#        single_move_time  round_time  mcts_win  maximal_number_of_playouts  \
# count         75.000000   75.000000      75.0                   75.000000
# mean           4.333333   14.533333       1.0                99280.146667
# std            3.322053   10.226269       0.0                79943.647609
# min            1.000000    2.000000       1.0                 1184.000000
# 25%            1.000000    2.000000       1.0                23262.500000
# 50%            4.000000   10.000000       1.0                89849.000000
# 75%            8.000000   20.000000       1.0               161229.500000
# max           10.000000   30.000000       1.0               289980.000000
#
#        max_tree_depth
# count            75.0
# mean              2.0
# std               0.0
# min               2.0
# 25%               2.0
# 50%               2.0
# 75%               2.0
# max               2.0

# %%
#MCTS zawsze wygrywa

# %%
aggressive.corr()
# Out:
#                             single_move_time  round_time  mcts_win  \
# single_move_time                    1.000000    0.838252       NaN
# round_time                          0.838252    1.000000       NaN
# mcts_win                                 NaN         NaN       NaN
# maximal_number_of_playouts          0.956620    0.760088       NaN
# max_tree_depth                           NaN         NaN       NaN
#
#                             maximal_number_of_playouts  max_tree_depth
# single_move_time                              0.956620             NaN
# round_time                                    0.760088             NaN
# mcts_win                                           NaN             NaN
# maximal_number_of_playouts                    1.000000             NaN
# max_tree_depth                                     NaN             NaN

# %%
aggressive.cov()
# Out:
#                             single_move_time     round_time  mcts_win  \
# single_move_time                    5.536934      31.781502       0.0
# round_time                         31.781502     259.615146       0.0
# mcts_win                            0.000000       0.000000       0.0
# maximal_number_of_playouts      94646.124146  514941.205462       0.0
# max_tree_depth                      0.000000       0.000000       0.0
#
#                             maximal_number_of_playouts  max_tree_depth
# single_move_time                          9.464612e+04             0.0
# round_time                                5.149412e+05             0.0
# mcts_win                                  0.000000e+00             0.0
# maximal_number_of_playouts                1.767899e+09             0.0
# max_tree_depth                            0.000000e+00             0.0

# %%
passive.corr()
# Out:
#                             single_move_time  round_time  mcts_win  \
# single_move_time                    1.000000    0.332972       NaN
# round_time                          0.332972    1.000000       NaN
# mcts_win                                 NaN         NaN       NaN
# maximal_number_of_playouts          0.991269    0.313829       NaN
# max_tree_depth                           NaN         NaN       NaN
#
#                             maximal_number_of_playouts  max_tree_depth
# single_move_time                              0.991269             NaN
# round_time                                    0.313829             NaN
# mcts_win                                           NaN             NaN
# maximal_number_of_playouts                    1.000000             NaN
# max_tree_depth                                     NaN             NaN

# %%
passive.cov()
# Out:
#                             single_move_time     round_time  mcts_win  \
# single_move_time                   10.181311       6.276151       0.0
# round_time                          6.276151      34.895397       0.0
# mcts_win                            0.000000       0.000000       0.0
# maximal_number_of_playouts     235622.425384  138101.979079       0.0
# max_tree_depth                      0.000000       0.000000       0.0
#
#                             maximal_number_of_playouts  max_tree_depth
# single_move_time                          2.356224e+05             0.0
# round_time                                1.381020e+05             0.0
# mcts_win                                  0.000000e+00             0.0
# maximal_number_of_playouts                5.549410e+09             0.0
# max_tree_depth                            0.000000e+00             0.0

# %%
random.corr()
# Out:
#                             single_move_time  round_time  mcts_win  \
# single_move_time                    1.000000    0.782303       NaN
# round_time                          0.782303    1.000000       NaN
# mcts_win                                 NaN         NaN       NaN
# maximal_number_of_playouts          0.979036    0.773896       NaN
# max_tree_depth                           NaN         NaN       NaN
#
#                             maximal_number_of_playouts  max_tree_depth
# single_move_time                              0.979036             NaN
# round_time                                    0.773896             NaN
# mcts_win                                           NaN             NaN
# maximal_number_of_playouts                    1.000000             NaN
# max_tree_depth                                     NaN             NaN

# %%
random.cov()
# Out:
#                             single_move_time     round_time  mcts_win  \
# single_move_time                   11.036036      26.576577       0.0
# round_time                         26.576577     104.576577       0.0
# mcts_win                            0.000000       0.000000       0.0
# maximal_number_of_playouts     260009.585586  632679.704505       0.0
# max_tree_depth                      0.000000       0.000000       0.0
#
#                             maximal_number_of_playouts  max_tree_depth
# single_move_time                          2.600096e+05             0.0
# round_time                                6.326797e+05             0.0
# mcts_win                                  0.000000e+00             0.0
# maximal_number_of_playouts                6.390987e+09             0.0
# max_tree_depth                            0.000000e+00             0.0

# %%
#Dane są bardzo dobrze skorelowane.

# %%
import seaborn as sns
sns.pairplot(aggressive)

# %%
sns.pairplot(passive)

# %%
sns.pairplot(random)

# %%
#Jak widać dane są bardzo dobrze skorelowane a MCTS zawsze wygrywa z agentami zachłannymi.
